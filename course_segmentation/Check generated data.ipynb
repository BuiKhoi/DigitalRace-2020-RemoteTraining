# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_FOLDER = '/media/buikhoi/TrainingDat/course_segmentation/'
TRAIN_FOLDER = DATA_FOLDER + 'train/'
VAL_FOLDER = DATA_FOLDER + 'val/'

# %%
rand = np.random.randint(9258)
count = 0
for dirr in os.listdir(TRAIN_FOLDER):
    if 'npz' in dirr:
        if count < rand:
            count += 1
            continue
        else:
            print(dirr)
            print(dirr)
            temp = np.load(TRAIN_FOLDER + dirr)
            img = temp['img']
            anno = temp['anno']
            break
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.imshow(img.astype('float'))
plt.title('Input image')
# img = np.expand_dims(img, 0)
# pred = run_model.predict(img)

plt.subplot(2, 2, 2)
plt.imshow(anno.astype('float'), 'gray')
plt.title('Label road')

# plt.subplot(2, 2, 3)
# plt.imshow(anno[:, :, 1].astype('float'), 'gray')
# plt.title('Label Line')

# plt.subplot(2, 2, 4)
# plt.imshow(anno[:, :, 2].astype('float'), 'gray')
# plt.title('Label sign')
# Out:
# 1607799516590.npz
# 1607799516590.npz
# Text(0.5, 1.0, 'Label road')

# %%
train_dir = TRAIN_FOLDER
for file in os.listdir(train_dir):
    temp = np.load(train_dir + file)
    img = temp['img']
    anno = temp['anno']
    for i in range(3):
        img[:, :, i] -= anno
    img = np.clip(img, 0, 1)
    cv2.imshow('Image', img.astype('float'))
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-afdcc70295ea> in <module>
#       7         img[:, :, i] -= anno
#       8     img = np.clip(img, 0, 1)
# ----> 9     cv2.imshow('Image', img.astype('float'))
#      10     if cv2.waitKey(1) & 0xFF == ord('q'):
#      11         break
#
# error: OpenCV(3.4.2) /tmp/build/80754af9/opencv-suite_1535558553474/work/modules/highgui/src/window.cpp:632: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Carbon support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
while True:
    cv2.imshow('image', np.random.random((100, 100)))
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-10-c26e61a18a06> in <module>
#       1 while True:
# ----> 2     cv2.imshow('image', np.random.random((100, 100)))
#       3     if cv2.waitKey(1) & 0xFF == ord('q'):
#       4         break
#       5 cv2.destroyAllWindows()
#
# error: OpenCV(3.4.2) /tmp/build/80754af9/opencv-suite_1535558553474/work/modules/highgui/src/window.cpp:632: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Carbon support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
cv2.__version__
# Out:
# '3.4.2'
